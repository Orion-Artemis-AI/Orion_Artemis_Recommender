# %%
### Init

# !pip install -U pymupdf4llm[ocr,layout]

# %%
import pymupdf.layout  # activate PyMuPDF-Layout in pymupdf
import pymupdf4llm
import pathlib

# The remainder of the script is unchanged
md_text = pymupdf4llm.to_markdown("/content/INSTRUKSI PRESIDEN REPUBLIK INDONESIA NOMOR 8 TAHUN 2025.pdf")

# now work with the markdown text, e.g. store as a UTF8-encoded file
pathlib.Path("/content/Output/INSTRUKSI PRESIDEN REPUBLIK INDONESIA NOMOR 8 TAHUN 2025.md").write_bytes(md_text.encode())

# %%
# import pymupdf.layout  # activate PyMuPDF-Layout in pymupdf
import pymupdf4llm
import pathlib

# The remainder of the script is unchanged
md_text = pymupdf4llm.to_markdown("/content/INSTRUKSI PRESIDEN REPUBLIK INDONESIA NOMOR 8 TAHUN 2025.pdf")

# now work with the markdown text, e.g. store as a UTF8-encoded file
pathlib.Path("/content/Output/INSTRUKSI PRESIDEN REPUBLIK INDONESIA NOMOR 8 TAHUN 2025_NoLayout.md").write_bytes(md_text.encode())
